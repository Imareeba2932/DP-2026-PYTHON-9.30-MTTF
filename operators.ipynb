# %%
a = 10
b = 20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 30
# -10
# 200
# 0.5

# %%
a = 10
a+=2
print(a)
# Out:
# 12

# %%
a*=2
print(a)
# Out:
# 24

# %%
x= 10
y= 7
z =11

not(x>y and x>z)
# Out:
# True

# %%
x= 10
y= 7
z =11

x>y or x>z
# Out:
# True

# %%
fruits = ['apple', 'banana', 'cherry', 'date', 'elderberry']
"mango" in fruits
# Out:
# False
