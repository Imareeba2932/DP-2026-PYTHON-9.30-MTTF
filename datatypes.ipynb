# %%
name = "Rahul Yadav"
print(name)
# Out:
# Rahul Yadav

# %%
poem = '''Johny JOhny yes papa
eating sugar no papa
telling a lie no papa'''

print(poem)
# Out:
# Johny JOhny yes papa
# eating sugar no papa
# telling a lie no papa

# %%
lst = [2,4,5,4,6,7,5,4,6,2,4,3,"apple","banana","grapes"]
print(lst)
# Out:
# [2, 4, 5, 4, 6, 7, 5, 4, 6, 2, 4, 3, 'apple', 'banana', 'grapes']

# %%
lst = (3,4,5,4,6,7,5,4,6,2,4,3,"apple","banana","grapes")
print(lst)
# Out:
# (3, 4, 5, 4, 6, 7, 5, 4, 6, 2, 4, 3, 'apple', 'banana', 'grapes')

# %%
lst = {2,4,5,4,6,7,5,4,6,2,4,3,"apple","banana","grapes"}
print(lst)
# Out:
# {2, 3, 4, 5, 6, 7, 'grapes', 'banana', 'apple'}

# %%
student = {
    "name" : "Alice",
    "age" : "21",
    "city" : "Lucknow"
}
print(student)
# Out:
# {'name': 'Alice', 'age': '21', 'city': 'Lucknow'}

# %%
type(student)
# Out:
# dict

# %% [markdown]
# `TYPE CASTING` is a process of converting one datatype into another datatype

# %%
a = input("Enter a number")
b = input("Enter a number")
print(a+b) #string conacatenation
# Out:
# 1020

# %%
a = input("Enter a number")
b = input("Enter a number")
x = int(a)
y = int(b)
print(x+y)
# Out:
# 30

# %%
a = int(input("Enter a number"))
b = int(input("Enter a number"))
print('sum of',a,"and",b,"is",a+b) 
print(f'sum of {a} and {b} is {a+b}')
# Out:
# sum of 10 and 20 is 30
# sum of 10 and 20 is 30
