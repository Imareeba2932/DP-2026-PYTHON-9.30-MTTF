# %% [markdown]
# - create a string
# - implement loop on it
# - implement indexing and slicing on it

# %%
a = "Hello World"
for i in a:
    print(i, end=" ")
# Out:
# H e l l o   W o r l d

# %%
print(a[0])
print(a[6])
print(a[0:5])
# Out:
# H
# W
# Hello
